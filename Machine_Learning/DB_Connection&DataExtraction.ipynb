# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine, inspect
from sqlalchemy.orm import sessionmaker, Session
from sqlalchemy.ext.automap import automap_base

# %%
db_string = f'postgres://postgres:umiami17@crypto.cbzxnt6iwq2t.us-east-2.rds.amazonaws.com:5432/postgres'
engine = create_engine(db_string)

# %%
Session = sessionmaker(bind=engine)
session = Session()

# %%
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['K_BITCOIN',
#  'K_ETHEREUM',
#  'K_CARDANO',
#  'COINS',
#  'BITCOIN',
#  'ETHEREUM',
#  'LITECOIN',
#  'CARDANO',
#  'RIPPLE',
#  'BINANCE',
#  'CHAINLINK',
#  'DOGECOIN',
#  'ETHEREUM_CLASSIC',
#  'POLKADOT',
#  'SOLANA',
#  'COSMOS']

# %%
column_names = inspector.get_columns('K_BITCOIN')
for column_name in column_names:
    print(column_name["name"])
# Out:
# SNo
# Name
# Symbol
# Date
# High
# Low
# Open
# Close
# Volume
# Marketcap

# %% [markdown]
# # Query

# %% [markdown]
# ### Bitcoin

# %%
bitcoin = engine.execute('SELECT * FROM public."K_BITCOIN"').fetchall()
bitcoin
# Out:
# [(1, 'Bitcoin', 'BTC', datetime.date(2013, 4, 29), 147.48800659179688, 134.0, 134.44400024414062, 144.5399932861328, 0.0, 1603768864.5),
#  (2, 'Bitcoin', 'BTC', datetime.date(2013, 4, 30), 146.92999267578125, 134.0500030517578, 144.0, 139.0, 0.0, 1542813125.0),
#  (3, 'Bitcoin', 'BTC', datetime.date(2013, 5, 1), 139.88999938964844, 107.72000122070312, 139.0, 116.98999786376953, 0.0, 1298954593.75),
#  (4, 'Bitcoin', 'BTC', datetime.date(2013, 5, 2), 125.5999984741211, 92.28189849853516, 116.37999725341797, 105.20999908447266, 0.0, 1168517495.25),
#  (5, 'Bitcoin', 'BTC', datetime.date(2013, 5, 3), 108.12799835205078, 79.0999984741211, 106.25, 97.75, 0.0, 1085995168.75),
#  (6, 'Bitcoin', 'BTC', datetime.date(2013, 5, 4), 115.0, 92.5, 98.0999984741211, 112.5, 0.0, 1250316562.5),
#  (7, 'Bitcoin', 'BTC', datetime.date(2013, 5, 5), 118.80000305175781, 107.14299774169922, 112.9000015258789, 115.91000366210938, 0.0, 1288693175.5),
# ...

# %%
btc = pd.DataFrame(bitcoin, columns=['SNo','Name','Symbol','Date','High','Low','Open','Close','Volume','Marketcap'])
btc
# Out:
#        SNo     Name Symbol        Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03    108.127998     79.099998
# ...    ...      ...    ...         ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06  35038.536363  33599.916169
#
#               Open         Close        Volume     Marketcap
# 0       134.444000    144.539993  0.000000e+00  1.603769e+09
# ...

# %%
btc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2991 entries, 0 to 2990
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   SNo        2991 non-null   int64
#  1   Name       2991 non-null   object
#  2   Symbol     2991 non-null   object
#  3   Date       2991 non-null   object
#  4   High       2991 non-null   float64
#  5   Low        2991 non-null   float64
#  6   Open       2991 non-null   float64
#  7   Close      2991 non-null   float64
#  8   Volume     2991 non-null   float64
#  9   Marketcap  2991 non-null   float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 233.8+ KB

# %%
# Export the data
btc.to_csv('Data/BTC.csv', index=False)

# %% [markdown]
# ## Ethereum

# %%
ethereum = engine.execute('SELECT * FROM public."K_ETHEREUM"').fetchall()
ethereum
# Out:
# [(1, 'Ethereum', 'ETH', datetime.date(2015, 8, 8), 2.7988100051879883, 0.7147250175476074, 2.793760061264038, 0.7533249855041504, 674188.0, 45486894.2408),
#  (2, 'Ethereum', 'ETH', datetime.date(2015, 8, 9), 0.8798099756240845, 0.629190981388092, 0.7061359882354736, 0.7018970251083374, 532170.0, 42399573.4991),
#  (3, 'Ethereum', 'ETH', datetime.date(2015, 8, 10), 0.7298539876937866, 0.6365460157394409, 0.7139890193939209, 0.7084479928016663, 405283.0, 42818364.3945),
#  (4, 'Ethereum', 'ETH', datetime.date(2015, 8, 11), 1.131410002708435, 0.6632350087165833, 0.7080870270729065, 1.0678600072860718, 1463100.0, 64569288.4328),
#  (5, 'Ethereum', 'ETH', datetime.date(2015, 8, 12), 1.2899399995803833, 0.8836079835891724, 1.058750033378601, 1.2174400091171265, 2150620.0, 73645010.9863),
#  (6, 'Ethereum', 'ETH', datetime.date(2015, 8, 13), 1.9650700092315674, 1.1719900369644165, 1.2222399711608887, 1.8276699781417847, 4068680.0, 110607191.674),
# ...

# %%
eth = pd.DataFrame(ethereum, columns=['SNo','Name','Symbol','Date','High','Low','Open','Close','Volume','Marketcap'])
eth
# Out:
#        SNo      Name Symbol        Date         High          Low  \
# 0        1  Ethereum    ETH  2015-08-08     2.798810     0.714725
# 1        2  Ethereum    ETH  2015-08-09     0.879810     0.629191
# 2        3  Ethereum    ETH  2015-08-10     0.729854     0.636546
# 3        4  Ethereum    ETH  2015-08-11     1.131410     0.663235
# 4        5  Ethereum    ETH  2015-08-12     1.289940     0.883608
# ...    ...       ...    ...         ...          ...          ...
# 2155  2156  Ethereum    ETH  2021-07-02  2155.596496  2021.824808
# 2156  2157  Ethereum    ETH  2021-07-03  2237.567155  2117.590013
# 2157  2158  Ethereum    ETH  2021-07-04  2384.286857  2190.837703
# 2158  2159  Ethereum    ETH  2021-07-05  2321.922836  2163.041394
# 2159  2160  Ethereum    ETH  2021-07-06  2346.294874  2197.919385
#
#              Open        Close        Volume     Marketcap
# 0        2.793760     0.753325  6.741880e+05  4.548689e+07
# ...

# %%
eth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2160 entries, 0 to 2159
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   SNo        2160 non-null   int64
#  1   Name       2160 non-null   object
#  2   Symbol     2160 non-null   object
#  3   Date       2160 non-null   object
#  4   High       2160 non-null   float64
#  5   Low        2160 non-null   float64
#  6   Open       2160 non-null   float64
#  7   Close      2160 non-null   float64
#  8   Volume     2160 non-null   float64
#  9   Marketcap  2160 non-null   float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 168.9+ KB

# %%
eth.to_csv('Data/ETH.csv', index=False)

# %% [markdown]
# ## Cardano

# %%
cardano = engine.execute('SELECT * FROM public."K_CARDANO"').fetchall()
cardano
# Out:
# [(1, 'Cardano', 'ADA', datetime.date(2017, 10, 2), 0.030087700113654137, 0.01996929943561554, 0.02460700087249279, 0.02593179978430271, 57641300.0, 628899051.78),
#  (2, 'Cardano', 'ADA', datetime.date(2017, 10, 3), 0.02742519974708557, 0.02068989910185337, 0.025756599381566048, 0.02081580087542534, 16997800.0, 539692714.905),
#  (3, 'Cardano', 'ADA', datetime.date(2017, 10, 4), 0.022806299850344658, 0.020864099264144897, 0.020864099264144897, 0.021931499242782593, 9000050.0, 568619547.504),
#  (4, 'Cardano', 'ADA', datetime.date(2017, 10, 5), 0.022153599187731743, 0.02085929922759533, 0.021951299160718918, 0.021488700062036514, 5562510.0, 557139040.67),
#  (5, 'Cardano', 'ADA', datetime.date(2017, 10, 6), 0.0215418990701437, 0.018359700217843056, 0.021358899772167206, 0.018539100885391235, 7780710.0, 480664553.411),
#  (6, 'Cardano', 'ADA', datetime.date(2017, 10, 7), 0.02105030044913292, 0.01761999912559986, 0.018413899466395378, 0.02094089984893799, 7411240.0, 542936191.429),
# ...

# %%
ada = pd.DataFrame(cardano, columns=['SNo','Name','Symbol','Date','High','Low','Open','Close','Volume','Marketcap'])
ada
# Out:
#        SNo     Name Symbol        Date      High       Low      Open  \
# 0        1  Cardano    ADA  2017-10-02  0.030088  0.019969  0.024607
# 1        2  Cardano    ADA  2017-10-03  0.027425  0.020690  0.025757
# 2        3  Cardano    ADA  2017-10-04  0.022806  0.020864  0.020864
# 3        4  Cardano    ADA  2017-10-05  0.022154  0.020859  0.021951
# 4        5  Cardano    ADA  2017-10-06  0.021542  0.018360  0.021359
# ...    ...      ...    ...         ...       ...       ...       ...
# 1369  1370  Cardano    ADA  2021-07-02  1.394397  1.286607  1.332942
# 1370  1371  Cardano    ADA  2021-07-03  1.441714  1.359664  1.394152
# 1371  1372  Cardano    ADA  2021-07-04  1.493717  1.382153  1.404008
# 1372  1373  Cardano    ADA  2021-07-05  1.461221  1.379284  1.461221
# 1373  1374  Cardano    ADA  2021-07-06  1.456887  1.393282  1.404712
#
#          Close        Volume     Marketcap
# 0     0.025932  5.764130e+07  6.288991e+08
# 1     0.020816  1.699780e+07  5.396927e+08
# ...

# %%
ada.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1374 entries, 0 to 1373
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   SNo        1374 non-null   int64
#  1   Name       1374 non-null   object
#  2   Symbol     1374 non-null   object
#  3   Date       1374 non-null   object
#  4   High       1374 non-null   float64
#  5   Low        1374 non-null   float64
#  6   Open       1374 non-null   float64
#  7   Close      1374 non-null   float64
#  8   Volume     1374 non-null   float64
#  9   Marketcap  1374 non-null   float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 107.5+ KB

# %%
ada.to_csv('Data/ADA.csv', index=False)
